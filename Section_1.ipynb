# %% [markdown]
# <a href="https://colab.research.google.com/github/3bdo-Yahya/Image-Processing/blob/main/Section_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install matplotlib
# !conda install numpy
# Out:
# ...
# /bin/bash: line 1: conda: command not found

# %%
import cv2
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
A=np.array([1,2,3,4,5,6,7,8])
B=A.reshape(2,2,2)
B
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
pythonList = [[1,2,3],[4,5,6]]
pythonList
# output: [[1, 2, 3], [4, 5, 6]]

numpyArray = np.array([[1,2,3],[4,5,6]])
numpyArray
# output: array([[1, 2, 3],
#                [4, 5, 6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
for i in numpyArray:
  for j in i:
    print(j)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in np.nditer(numpyArray):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
imgPath='/content/drive/MyDrive/Colab Notebooks/123.jpg'
image = cv2.imread(imgPath,cv2.IMREAD_COLOR)
print(image)
# Out:
# [[[ 90 132 179]
#   [ 93 133 181]
#   [ 98 136 184]
#   ...
#   [202 200 200]
#   [202 200 200]
#   [202 200 200]]
#
#  [[ 87 129 176]
#   [ 90 131 176]
#   [ 96 134 182]
#   ...
#   [202 200 200]
#   [202 200 200]
#   [202 200 200]]
#
#  [[ 82 123 168]
#   [ 85 127 170]
#   [ 91 130 175]
#   ...
#   [202 200 200]
#   [202 200 200]
#   [202 200 200]]
#
#  ...
#
#  [[197 195 194]
#   [197 195 194]
#   [197 195 194]
#   ...
#   [202 200 199]
#   [202 200 199]
#   [202 200 199]]
#
#  [[199 197 196]
#   [199 197 196]
#   [199 197 196]
#   ...
#   [202 200 199]
#   [202 200 199]
#   [202 200 199]]
#
#  [[200 198 197]
#   [201 199 198]
#   [201 199 198]
#   ...
#   [202 200 199]
#   [202 200 199]
#   [202 200 199]]]

# %%
plt.imshow(image)

plt.show() # Display the plot

# %%
# Convert image from BGR to RGB color format
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# This is useful because matplotlib expect images in RGB format,
# while OpenCV defaults to BGR.

plt.imshow(image_RGB)
plt.axis('off')  # Hide axis

plt.show()

# %%
print(image.shape)
# Out:
# (820, 820, 3)
